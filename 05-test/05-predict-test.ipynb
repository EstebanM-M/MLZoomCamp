# %%
# %autosave 0
# Out:
# Autosave disabled

# %%
import requests

url = 'http://127.0.0.1:9696/predict'

# %%
customer={'gender': 'male',
 'partner': 'yes',
 'dependents': 'yes',
 'phoneservice': 'yes',
 'multiplelines': 'no',
 'internetservice': 'fiber_optic',
 'onlinesecurity': 'no',
 'onlinebackup': 'yes',
 'deviceprotection': 'no',
 'techsupport': 'no',
 'streamingtv': 'yes',
 'streamingmovies': 'yes',
 'contract': 'month-to-month',
 'paperlessbilling': 'yes',
 'paymentmethod': 'mailed_check',
 'seniorcitizen': 1,
 'tenure': 32,
 'monthlycharges': 93.95,
 'totalcharges': 28061.45}

# %%
response = requests.post(url, json=customer).json()
response
# Out:
# {'churn': True, 'churn_probabilty': 0.9998052462586691}

# %%
if response['churn'] == True:
    print('sending promo email to customer: XXXX')
else:
    print('No worries')
# Out:
# sending promo email to customer: XXXX
