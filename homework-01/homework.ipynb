# %%
data = "wget https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv"

# %%
# !wget $data
# Out:
# --2026-09-10 20:58:33--  http://wget/
# Resolving wget (wget)... failed: Name or service not known.
# wget: unable to resolve host address ‘wget’
# --2026-09-10 20:58:33--  https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 635180 (620K) [text/plain]
# Saving to: ‘car_fuel_efficiency_2026.csv’
#
# car_fuel_efficiency 100%[===================>] 620.29K  --.-KB/s    in 0.02s
#
# 2026-09-10 20:58:34 (30.5 MB/s) - ‘car_fuel_efficiency_2026.csv’ saved [635180/635180]
#
# FINISHED --2026-09-10 20:58:34--
# Total wall clock time: 0.2s
# Downloaded: 1 files, 620K in 0.02s (30.5 MB/s)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %%
df = pd.read_csv('car_fuel_efficiency_2026.csv')
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# # Q1. Pandas version

# %%
pd.__version__
# Out:
# '3.0.5'

# %% [markdown]
# # Q2. Records count
#
# How many records are in the dataset?
#
# - 5000
# - 9000
# - 10000
# - 15000

# %%
df.count() # Answer C=10000
# Out:
# model_year             10000
# origin                 10000
# fuel_type              10000
# drivetrain             10000
# num_doors              10000
# engine_displacement    10000
# num_cylinders          10000
# horsepower              9123
# vehicle_weight         10000
# acceleration            9736
# fuel_efficiency_mpg    10000
# dtype: int64

# %% [markdown]
# # Q3. Fuel types
#
# How many fuel types are presented in the dataset?
#
# - 1
# - 2
# - 3
# - 4

# %%
df.columns
# Out:
# Index(['model_year', 'origin', 'fuel_type', 'drivetrain', 'num_doors',
#        'engine_displacement', 'num_cylinders', 'horsepower', 'vehicle_weight',
#        'acceleration', 'fuel_efficiency_mpg'],
#       dtype='str')

# %%
df.fuel_type.nunique() # Answer: C = 3
# Out:
# 3

# %% [markdown]
# # Q4. Missing values
#
# How many columns in the dataset have missing values?
#
# - 0
# - 1
# - 2
# - 3
# - 4

# %%
df.columns[(df.isnull().sum()>0)].values #answer c=2
# Out:
# <StringArray>
# ['horsepower', 'acceleration']
# Length: 2, dtype: str

# %%
(df.isnull().sum()>0).sum()
# Out:
# np.int64(2)

# %% [markdown]
# # Q5. Max fuel efficiency
#
# What's the maximum fuel efficiency of cars from Asia?
#
# - 21.2
# - 31.2
# - 41.2
# - 51.2

# %%
df[df['origin']=='Asia'].fuel_efficiency_mpg.max() # Answer C = 41.2
# Out:
# np.float64(41.2)

# %% [markdown]
# # Q6. Median value of horsepower
#
# 1. Find the median value of the horsepower column in the dataset.
# 2. Next, calculate the most frequent value of the same horsepower column.
# 3. Use the fillna method to fill the missing values in the horsepower column with the most frequent value from the previous step.
# 4. Now, calculate the median value of horsepower once again.
#
# Has it changed?
#
# - Yes, it increased
# - Yes, it decreased
# - No

# %%
print(df.horsepower.median())
print(df.horsepower.mode().values[0])
mode = df.horsepower.mode().values[0]
df.horsepower = df.horsepower.fillna(mode)

print(df.horsepower.median())
# Out:
# 252.0
# 252.0
# 252.0

# %% [markdown]
# # Q7. Sum of weights
#
# 1. Select all the cars from Asia
# 2. Select only columns vehicle_weight and model_year
# 3. Select the first 7 values
# 4. Get the underlying NumPy array. Let's call it X.
# 5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# 6. Invert XTX.
# 6. Create an array y with values [1100, 1300, 800, 900, 1000, 1100, 1200].
# 7. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# 8. What's the sum of all the elements of the result?
#
# Note: You just implemented linear regression. We'll talk about it in the next lesson.
#
# - 0.0369
# - 0.369
# - 3.69
# - 36.9

# %%
X = np.array(df.loc[df.origin=='Asia', ['vehicle_weight', 'model_year']].head(7))
XTX = np.matmul(X.T, X)
X_inv = np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

w = np.matmul(X_inv, X.T)

np.matmul(w, y).sum() # Answer = B. 0.369
# Out:
# np.float64(0.36919696904925486)
